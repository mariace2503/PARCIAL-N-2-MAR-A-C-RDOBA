# %% [markdown]
# <a href="https://colab.research.google.com/github/mariace2503/PARCIAL-N-2-MAR-A-C-RDOBA/blob/main/PARCIALN2MARIACORDOBA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x1=[0.000000,0.011400,0.042800,0.084700,0.188500,0.233400,0.385400,0.421000,0.488200,0.787200,0.959200,1.000000]
TK=[474.03,463.81,453.60,425.76,389.51,367.58,345.35,338.24,328.52,304.69,299.59,298.88]
y1=[0.000000,0.318400,0.530700,0.822800,0.983200,0.990000,0.998300,0.999000,0.999000,0.999000,0.999000,1.000000]
plt.plot(x1,TK,color="blue")
plt.plot(x1,TK,"ko",markersize=4)
plt.plot(y1,TK,color="black")
plt.plot(y1,TK,"ko",markersize=4)
plt.xlabel("x1,y1")
plt.ylabel("Temperatura/k")
plt.title("T/K vs x1-y1")
plt.plot()
# Out:
# []

# %%
url="https://raw.githubusercontent.com/mariace2503/PARCIAL-N-2-MAR-A-C-RDOBA/main/TABLA%20DE%20DATOS%20PARCIAL.csv"
df=pd.read_csv(url)
df
# Out:
#          Name  NA Symbol          Family    PF      PE  Densidad     PA  \
# 0    hydrogen   1      H        Hydrogen    14    20.0   899.000    1.0
# 1      helium   2     He       Noble gas     1     4.0     1.785    4.0
# 2     lithium   3     Li    Alkali Metal   454  1619.0     0.530    6.9
# 3   beryllium   4     Be  Alkaline Earth  1560  2757.0     1.850    9.0
# 4       boron   5      B           Boron  2365  3931.0     2.340   10.8
# ..        ...  ..    ...             ...   ...     ...       ...    ...
# 68   polonium  84     Po       Chalcogen   527  1235.0     9.300  209.0
# 69   astatine  85     At         Halogen   575   607.0       NaN  210.0
# 70      radon  86     Rn       Noble gas   202   211.0     9.730  222.0
# 71   francium  87     Fr    Alkali Metal   300     NaN       NaN  223.0
# 72     radium  88     Ra  Alkaline Earth   973  2010.0     5.000  226.0
#
#     RadioAtomico  PrimeraIP  specific heatcapacity  thermal conductivity  \
# ...

# %%
ebullición=df["PE"]
fusión=df["PF"]
NúmeroAT=df["PA"]
plt.plot(NúmeroAT,ebullición,color="green")
plt.plot(NúmeroAT,fusión,color="blue")
plt.xlabel("PE y PF")
plt.ylabel("Número Atómico")
plt.title("Punto de Ebullición (PE) y Punto de fusión (PF) vs Número Atómico N")
plt.show()

# %%
DNA="..."
n=DNA.count("A")
m=DNA.count("C")
y=DNA.count("T")
b=DNA.count("G")
patrón=DNA.count("TGATCA")
print("nA=",n)
print("mA=",m)
print("yA=",y)
print("bA=",b)
print("patrón=",patrón)
# Out:
# nA= 136
# mA= 122
# yA= 174
# bA= 108
# patrón= 8

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

x=np.arange(0,10,1)
y=3.0*x*np.exp(-1.5*x)*np.sin(2*x*np.pi)
plt.plot(x,y)
plt.show()
